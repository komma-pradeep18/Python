# %%
from pandas import read_csv
import seaborn as sns
import numpy as np
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2,f_regression,f_classif
dataframe=sns.load_dataset('tips')
dataframe
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
from sklearn.preprocessing import LabelEncoder
lb=LabelEncoder()
dataframe['sex']=lb.fit_transform(dataframe['sex'])
dataframe['smoker']=lb.fit_transform(dataframe['smoker'])
dataframe['day']=lb.fit_transform(dataframe['day'])
dataframe['time']=lb.fit_transform(dataframe['time'])

# %%
X=dataframe.drop('tip',axis=1)
Y=dataframe.tip

# %%
X
# Out:
#      total_bill  sex  smoker  day  time  size
# 0         16.99    0       0    2     0     2
# 1         10.34    1       0    2     0     3
# 2         21.01    1       0    2     0     3
# 3         23.68    1       0    2     0     2
# 4         24.59    0       0    2     0     4
# ..          ...  ...     ...  ...   ...   ...
# 239       29.03    1       0    1     0     3
# 240       27.18    0       1    1     0     2
# 241       22.67    1       1    1     0     2
# 242       17.82    1       0    1     0     2
# 243       18.78    0       0    3     0     2
#
# [244 rows x 6 columns]

# %%
Y
# Out:
# 0      1.01
# 1      1.66
# 2      3.50
# 3      3.31
# 4      3.61
#        ...
# 239    5.92
# 240    2.00
# 241    2.00
# 242    1.75
# 243    3.00
# Name: tip, Length: 244, dtype: float64

# %%
test = SelectKBest(score_func=f_regression,k=4).fit(X,Y)
test
# Out:
# SelectKBest(k=4, score_func=<function f_regression at 0x0000029782C8E700>)

# %%
np.round(test.scores_4)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 np.round(test.scores_4)
#
# AttributeError: 'SelectKBest' object has no attribute 'scores_4'

# %%
dataframe.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
test.get_feature_name_out()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 test.get_feature_name_out()
#
# AttributeError: 'SelectKBest' object has no attribute 'get_feature_name_out'

# %%
dataframe.columns[test.get_support(indices=True)]
# Out:
# Index(['total_bill', 'tip', 'day', 'time'], dtype='object')

# %%
dataframe.columns[np.where(test.pvalues_<0.05)]
# Out:
# Index(['total_bill', 'time'], dtype='object')
